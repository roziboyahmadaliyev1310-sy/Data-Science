# %% [markdown]
# <a href="https://colab.research.google.com/github/roziboyahmadaliyev1310-sy/Data-Science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Write your C code to a file
# %%writefile hello.c
#include <stdio.h>

int main() {
    printf("Hello, World!\n");
    return 0;
}
# Out:
# Overwriting hello.c

# %%
# !gcc hello.c -o hello
# !./hello
# Out:
# Hello, World!

# %%
# %%writefile hello.c
# #include <stdio.h>
# int main() {
#     int x = 10;
#     int *ptr = &x;
#     printf("Value: %d\n", *ptr);
#     return 0;
# }
# Out:
# Overwriting hello.c

# %%
# !gcc hello.c -o hello && ./hello
# Out:
# Value: 10
